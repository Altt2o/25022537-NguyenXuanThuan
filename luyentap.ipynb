# %% [markdown]
# Bài 1

# %%
a = int(input())
print(a*2)
# Out:
# 4

# %% [markdown]
# Bài 2

# %%
a, b = map(int, input().split())
if a<b:
    print(f"{a*b - ((a/2)**2)*3.14:.2f}")
else:
    print("error")
# Out:
# error

# %% [markdown]
# Bài 3

# %%
a = input()
if a.isupper():
    print(a.lower())
elif a.islower():
    print(a.upper())    
else:
    print(a)
# Out:
# d

# %% [markdown]
# Bài 4

# %%
a = input()
if a.isupper() or a.islower():
    print(f"{a}: Là kí tự alphabet")
else:
    print(f"{a}: Không phải là kí tự alphabet")
# Out:
# G: Là kí tự alphabet

# %% [markdown]
# Bài 5

# %%
a = input()
y = a.lower()
if a == 'A':
    s = 'z'
else:
    s = chr(ord(y)-1)
print(f"Kí tự liền trước: {s}")
# Out:
# Kí tự liền trước: g

# %% [markdown]
# Bài 6

# %%
a, b, c = map(float, input().split())
if a+b>c or b+c>a or a+c>b:
    y = (a+b+c)/2
    print(f"{(y*(y-a)*(y-b)*(y-c))**(1/2):.1f}")
else:
    print("Không phải 3 cạnh của 1 tam giác5")
# Out:
# 11.5

# %% [markdown]
# Bài 7

# %%
a = input()
if len(a) >= 20:
    print(a[4])
    print(a[8])
else:
    print("Không đủ kí tự")
# Out:
# a
# f

# %% [markdown]
# Bài 8

# %%
c = str(input())
a = int(input())
b = int(input())
y = abs(b-a)
print("Họ và tên:", c)
if 50 >= y >= 0:
    x = y*1984*1.08
elif 100 >= y >= 51:
    x = (50*1984 + (y-50)*2050)*1.08
elif 200 >= y >= 101:
    x = (50*(1984+2050) + (y-100)*2380)*1.08
elif 300 >= y >= 201:
    x = (50*(1984+2050) + 100*2380 + (y-200)*2998)*1.08
elif 400 >= y >= 301:
    x = (50*(1984+2050) + 100*(2380+2998) +(y-300)*3350)*1.08
elif y >= 401:
    x = (50*(1984+2050) + 100*(2380+2998+3350) + (y-400)*3460)*1.08
print(f"Tiền phải trả là: {x:.0f}")
# Out:
# Họ và tên: Nguyen Xuan Hai
# Tiền phải trả là: 1855505

# %% [markdown]
# Một số bài tập khác

# %% [markdown]
# Bài 1

# %%
a = int(input())
if a % 2 == 0:
    print(a,": Là số chẵn")
else:
    print(a,": Là số lẻ")
# Out:
# 341 : Là số lẻ

# %% [markdown]
# Bài 2

# %%
a = int(input())
if a % 10 == 5:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# Bài 3

# %%
a = int(input())
if a % 3 == 0 or a % 5 == 0:
    print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# Bài 4

# %%
a = int(input())
if 2026 - a >= 18:
    print("Đủ tuổi để bầu cử")
elif 1 <= 2026 - a <= 18:
    print("không đủ tuổi bầu cử")
elif 2026 - a <= 0:
    print("ERROR")
# Out:
# không đủ tuổi bầu cử

# %% [markdown]
# Bài 5

# %%
a = float(input())
b = float(input())
if a > b:
    print(a)
elif b > a:
    print(b)
elif a == b:
    print("Hai số bằng nhau")
# Out:
# 45.0

# %% [markdown]
# Bài 6

# %%
a = str(input())
if a.isupper() or a.islower():
    print(a,': Là chữ cái')
elif a.isalnum(): # xem a có là số hay không
    print(a,': Là số')
else:
    print(a,': Không phải là chữ cái hoặc số')
# Out:
# @# : Không phải là chữ cái hoặc số

# %% [markdown]
# Bài 7

# %%
a = float(input())
if a < 5:
    print("Học lực yếu")
elif 6.5 > a > 5:
    print("Học lực trung bình")
elif 8 > a > 6.5:
    print("Học lực khá")
elif 10 > a > 8:
    print("Học lực giỏi")
# Out:
# Học lực giỏi

# %% [markdown]
# Bài 8

# %%
a = int(input())
if a % 400 == 0 or a % 4 == 0 and a % 100 != 0:
    print("Là năm nhuận")
else:
    print("Không là năm nhuận")
# Out:
# Là năm nhuận

# %% [markdown]
# Bài 9

# %%
a = int(input())
if a == 0:
    print("Không")
elif a == 1:
    print("Một")
elif a == 2:
    print("Hai")
elif a == 3:
    print("Ba")
elif a == 4:
    print("Bốn")
elif a == 5:
    print("Năm")
elif a == 6:
    print("Sáu")
elif a == 7:
    print("Bảy")
elif a == 8:
    print("Tám")
elif a == 9:
    print("Chín")
else:
    print("ERROR")
# Out:
# Bốn

# %% [markdown]
# BÀi 10

# %%
a = float(input())
if 10 >= a >= 4:
    print("Qua môn")
elif 0<= a < 4:
    print("Trượt môn")
else:
    print("ERROR")
# Out:
# Qua môn

# %% [markdown]
# Bài 11

# %%
a = int(input())
if 2025 - a >= 18:
    print("Đủ 18 tuổi")
elif 18 >= 2025 - a >= 0:
    print("Chưa đủ 18 tuổi")
else:
    print("ERROR")
# Out:
# Đủ 18 tuổi
